# %%
#error handling in python
try: #try block - code that may raise an exception
    print(x) #x is not defined, so this will raise a NameError
except NameError: #except block - code to handle the exception
    print("x is not defined")
finally: #finally block - code to execute regardless of whether an exception was raised or not
    print("This will always be executed")
# Out:
# 10
# This will always be executed
