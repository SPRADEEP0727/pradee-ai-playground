# %%
#functions in python

def greet(name):
    print("Hello this a function, " + name)

def add(a, b):
    return a + b

greet("pradeep")

result = add(5, 10)
print(result)
# Out:
# Hello this a function, pradeep
# 15
